# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# set the plots to display in the Jupyter notebook
# %matplotlib inline

# %%
# 9.1 Line Plot

# A. Make a dataframe called foot using the "./international_football_results.csv" file
#    Perform a few exploratory data analysis operations before working with the data set

# We'll use the .to_datetime method and .dt.year property to set the "year" column from a string to an integer
foot = pd.read_csv("./international_football_results.csv")
foot["year"] = pd.to_datetime(foot.date).dt.year
print(foot.shape)
print(f'{foot.describe()}')
foot.head()
# Out:
# (39669, 10)
#          home_score    away_score          year
# count  39669.000000  39669.000000  39669.000000
# mean       1.747763      1.187880   1989.278303
# std        1.746964      1.399707     23.997291
# min        0.000000      0.000000   1872.000000
# 25%        1.000000      0.000000   1977.000000
# 50%        1.000000      1.000000   1996.000000
# 75%        2.000000      2.000000   2008.000000
# max       31.000000     21.000000   2018.000000
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  year
# ...

# %%
# B. Let's chart how many games occured in each year:
foot.plot('year')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# The years are out of order! Fortunately, we can sort our column by its index with sort_index()

foot.sort_index()
foot.index.name = "index"
foot.head()
foot['year'].value_counts().sort_index()
# Out:
# 1872       1
# 1873       1
# 1874       1
# 1875       1
# 1876       2
#         ...
# 2014     857
# 2015    1001
# 2016     918
# 2017     908
# 2018     390
# Name: year, Length: 147, dtype: int64

# %%
# Finally, we're ready to plot the change over time with .plot()
foot['year'].value_counts().sort_index().plot(figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
# 9.2 Bar Charts
# A. Let's see how many games each country played, represented as a bar chart
foot['country'].value_counts().sort_index().plot.bar(figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
# B. Now let's plot the occurence of specific scores for the home team
foot['home_score'].value_counts().sort_index().plot.bar(figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
# C. Instead of sorting from highest to lowest value, let's sort the x axis in ascending order
plt.xlabel('home score')
plt.ylabel('games played')
foot['home_score'].value_counts(ascending = True).plot.bar(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='home score', ylabel='games played'>

# %%
# BONUS: Compare the home_score and away_score value counts to analyze home field advantage
# You will need to use the .apply method to use value_counts on each column of a dataframe

# foot['away_score'].value_counts().plot()
# foot['home_score'].value_counts().plot()
# plt.show()

foot[['home_score','away_score']].apply(lambda x: x.value_counts()).plot.bar(figsize=(16,9))
foot[['home_score','away_score']].apply(lambda x: x.value_counts()).plot(figsize=(16,9))
plt.xlabel('number of games')
plt.ylabel("points scored in game")
plt.show()
#home teams have less 0 and 1 point games, more 2+ point games, comparatively

# %%
# 9.3 Histograms
# A. Let's start with a new dataset. Create a dataframe called choc from the './chocolate_reviews.csv' file
#    Inspect the data using some exploratory data analysis methods
choc = pd.read_csv("./chocolate_ratings.csv")
choc.head()
choc.describe()
choc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company
# (Maker-if known)         1795 non-null   object
#  1   Specific Bean Origin
# or Bar Name  1795 non-null   object
#  2   REF                               1795 non-null   int64
#  3   Review
# Date                       1795 non-null   int64
#  4   Cocoa
# Percent                     1795 non-null   object
#  5   Company
# Location                  1795 non-null   object
#  6   Rating                            1795 non-null   float64
#  7   Bean
# Type                         1794 non-null   object
#  8   Broad Bean
# Origin                 1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
# B. Now, let's explore the distribution of ratings
#    i. Start by plotting the Rating column in a histogram
choc.Rating.plot.hist(figsize=(16,9),bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#    ii. Looking good! Let's see how granular we can get
#        Modify the number of bins to change how ranges are distributed
plt.xlabel('Rating')
plt.ylabel("Observations")
plt.title('Chocolate ratings')
choc.Rating.plot.hist(figsize=(16,9),bins=30)
# Out:
# <AxesSubplot:title={'center':'Chocolate ratings'}, xlabel='Rating', ylabel='Frequency'>

# %%
#    iii. Now, let's add some descriptive labels to our chart using matplotlib

choc.Rating.plot.hist(figsize=(16,9),bins=30)
plt.xlabel('Rating')
plt.ylabel("Observations")
plt.title('Chocolate ratings')
# Out:
# Text(0.5, 1.0, 'Chocolate ratings')

# %%
# 9.4 Scatter Plots
# A. Is there a connection between Review Date and Rating? Plot them with a scatter plot
choc.plot.scatter(x='Review\nDate',y='Rating')

# Why is this graph not so helpful?
#information is disconnected, we see that chocolate got rated 3.0 in 2006, but not what that 
# chocolate was, who it was made by, where the beans were sourced
# Out:
# <AxesSubplot:xlabel='Review\nDate', ylabel='Rating'>

# %%
# B. Explore the data from avocado.csv, then scatter plot correlation between Total Volume and AveragePrice
avo = pd.read_csv("./avocado.csv")
avo.head()
avo.plot.scatter(x='AveragePrice',y='Total Volume')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
# 9.5 Visualizations to Hypotheses
# Create visualizations around any of the above datasets or our superstore datasets
# For at least one of the visualizations, attach a hypothesis or specific claim the chart supports


# perc_sort = choc.copy()
# perc_sort['Cocoa\nPercent'] = perc_sort['Cocoa\nPercent'].str.strip('%').astype(float)
# #perc_sort[['Cocoa\nPercent']].apply(lambda x: x.value_counts(ascending=True)).plot(figsize=(16,9))
# perc_sort['Cocoa\nPercent'].value_counts().sort_index().plot(x='Cocoa\nPercent',y='Rating',kind='bar',figsize=(16,9))
# #most cocoa rated fall are approximately 70% cocoa
# perc_sort[perc_sort['Review\nDate']==2016].plot.bar(x='Review\nDate',y='Rating')
# perc_sort.plot(x='Rating', y='Company\nLocation')

xlen= [0,0.5,1,1.5,2,2.5,3]
avo.plot.scatter(x='AveragePrice',y='Total Volume')
avo[avo['region']=='Albany'].plot.scatter(x='AveragePrice',y='Total Volume')
#albany avos have a tighter bounded price point than average, higher minimum, lower maximum
#does better than average on lower total volume
avo[avo['type']=='conventional'].plot.scatter(x='AveragePrice',y='Total Volume')
#
avo[avo['type']=='organic'].plot.scatter(x='AveragePrice',y='Total Volume')
#organic has a higher price point than conventional
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
avo.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...
